# %%
from ollama import chat
from ollama import ChatResponse

response: ChatResponse = chat(model='gemma3', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# The blue color of the sky is a fascinating phenomenon caused by a process called **Rayleigh scattering**. Here's a breakdown of how it works:
#
# **1. Sunlight and its Colors:**
#
# * Sunlight is actually made up of *all* the colors of the rainbow. You can see this when light passes through a prism or when you see a rainbow after a rainstorm.
#
# **2. Entering the Atmosphere:**
#
# * When sunlight enters the Earth’s atmosphere, it collides with tiny air molecules – mainly nitrogen and oxygen.
#
# **3. Rayleigh Scattering:**
#
# * This collision causes the light to scatter in different directions.  **Rayleigh scattering** is *specifically* how light scatters when the particles it hits are much smaller than the wavelength of the light.
# * **Shorter wavelengths scatter *more* than longer wavelengths.** This is the key! Blue and violet light have shorter wavelengths than other colors like red and orange.
#
# **4. Why Blue, Not Violet?**
#
# * Violet light is actually scattered even *more* than blue light. However, there are a couple of reasons we see a blue sky instead of a violet one:
#    * **Sunlight emits less violet light:** The sun simply emits less violet light to begin with.
#    * **Our eyes are more sensitive to blue:** Human eyes are more sensitive to blue light than violet light.
#
#
# **Think of it like this:** Imagine throwing small pebbles (blue light) and large rocks (red light) at a bumpy surface. The small pebbles will bounce off in all directions, while the large rocks will mostly continue straight.
#
# **In short: Blue light gets scattered more by the atmosphere and reaches our eyes from all directions, making the sky appear blue.**
#
# ---
#
# **Resources for further learning:**
#
# * **NASA - Why is the sky blue?** [https://science.nasa.gov/sky-science/why-is-the-sky-blue/](https://science.nasa.gov/sky-science/why-is-the-sky-blue/)
# * **Wikipedia - Rayleigh scattering:** [https://en.wikipedia.org/wiki/Rayleigh_scattering](https://en.wikipedia.org/wiki/Rayleigh_scattering)
#
#
#
# Do you want to delve deeper into any specific aspect of this explanation, such as:
#
# *   Why sunsets are red?
# *   How this affects other planets?
# The blue color of the sky is a fascinating phenomenon caused by a process called **Rayleigh scattering**. Here's a breakdown of how it works:
#
# **1. Sunlight and its Colors:**
#
# * Sunlight is actually made up of *all* the colors of the rainbow. You can see this when light passes through a prism or when you see a rainbow after a rainstorm.
#
# **2. Entering the Atmosphere:**
#
# * When sunlight enters the Earth’s atmosphere, it collides with tiny air molecules – mainly nitrogen and oxygen.
#
# **3. Rayleigh Scattering:**
#
# * This collision causes the light to scatter in different directions.  **Rayleigh scattering** is *specifically* how light scatters when the particles it hits are much smaller than the wavelength of the light.
# * **Shorter wavelengths scatter *more* than longer wavelengths.** This is the key! Blue and violet light have shorter wavelengths than other colors like red and orange.
#
# **4. Why Blue, Not Violet?**
#
# * Violet light is actually scattered even *more* than blue light. However, there are a couple of reasons we see a blue sky instead of a violet one:
#    * **Sunlight emits less violet light:** The sun simply emits less violet light to begin with.
#    * **Our eyes are more sensitive to blue:** Human eyes are more sensitive to blue light than violet light.
#
#
# **Think of it like this:** Imagine throwing small pebbles (blue light) and large rocks (red light) at a bumpy surface. The small pebbles will bounce off in all directions, while the large rocks will mostly continue straight.
#
# **In short: Blue light gets scattered more by the atmosphere and reaches our eyes from all directions, making the sky appear blue.**
#
# ---
#
# **Resources for further learning:**
#
# * **NASA - Why is the sky blue?** [https://science.nasa.gov/sky-science/why-is-the-sky-blue/](https://science.nasa.gov/sky-science/why-is-the-sky-blue/)
# * **Wikipedia - Rayleigh scattering:** [https://en.wikipedia.org/wiki/Rayleigh_scattering](https://en.wikipedia.org/wiki/Rayleigh_scattering)
#
#
#
# Do you want to delve deeper into any specific aspect of this explanation, such as:
#
# *   Why sunsets are red?
# *   How this affects other planets?
